# %%
import pandas as pd
pd.read_csv('/home/huser/airflow_workspace/airflow/dags/Jobs/jobs_daily.csv')
# Out:
#                                               job_link  \
# 0    https://fr.linkedin.com/jobs/view/d%C3%A9velop...
# 1    https://fr.linkedin.com/jobs/view/technicien-n...
# 2    https://fr.linkedin.com/jobs/view/biochimiste-...
# 3    https://fr.linkedin.com/jobs/view/ing%C3%A9nie...
# 4    https://fr.linkedin.com/jobs/view/biochimiste-...
# ..                                                 ...
# 789  https://www.glassdoor.fr/job-listing/psycholog...
# 790  https://www.glassdoor.fr/job-listing/charg%C3%...
# 791  https://www.glassdoor.fr/job-listing/d%C3%A9ve...
# 792  https://www.glassdoor.fr/job-listing/d%C3%A9ve...
# 793  https://www.glassdoor.fr/job-listing/charg%C3%...
#
#                                               job_name  \
# 0              DÉVELOPPEUR DEVOPS POUR INTELLIGENT RPA
# 1                     TECHNICIEN.NE ANALYSE BIOLOGIQUE
# 2                                    BIOCHIMISTE (H/F)
# 3                          Ingénieur Applicatif SI H/F
# ...
